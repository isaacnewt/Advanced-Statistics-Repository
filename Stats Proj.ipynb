# %%
#AAcell100
x = np.arange(p.ppf(0.01, mu), p.ppf(0.99, mu))

fig, ax = plt.subplots()

ax.plot(x, p.pmf(x, mu), 'bo', ms=8, label='poisson pmf')
ax.vlines(x, 0, p.pmf(x, mu), colors='r', lw=5, alpha=0.5)

plt.axvline(mu, label='quartiles', c='tab:brown', linestyle='dotted')
plt.axvline(var, c='tab:green', linestyle='dotted')

ax.set_xlabel('$x$', fontsize=15)
ax.set_ylabel('$f_x(x)$', fontsize=15)
# ax.vlines(mean, 0.14, 0.16, colors='tab:red')
# ax.vlines(var, 0.14, 0.16, colors='tab:red', linewidth=3)
ax.set_title('Poisson distribution for $\mu=$'+str(mu)+', $\sigma=$'+str(sigma), fontsize=15)
ax.legend(loc='best', frameon=True)
ax.grid(True)
plt.savefig("./H1.pdf", format='pdf')
plt.show()

# %%
#AAcell93
import numpy as np
import matplotlib.pyplot as plt
from scipy.stats import poisson as p

mu =77
sigma = 77
mean, var, skew, kurt = p.stats(mu =mu, loc=0, moments='mvsk')

#AAcell95
x = np.arange(p.ppf(0.01, mu), p.ppf(0.99, mu))

fig, ax = plt.subplots()
ax.plot(x, p.pmf(x, mu), 'bo', ms=8, label='poisson pmf')
ax.vlines(x, 0, p.pmf(x, mu), colors='b', lw=5, alpha=0.5)

ax.set_xlabel('$x$', fontsize=15)
ax.set_ylabel('$f_{\mu, \sigma}(x)$', fontsize=15)
ax.set_title('Poisson distribution for $\mu=$'+str(mu)+', $\sigma=$'+str(sigma), fontsize=15)
ax.legend(loc='best', frameon=True)
ax.grid(True)
plt.show()

# %%
p.stats

# %%
mean, var, skew, kurt
# Out:
# (array(77.), array(77.), array(0.11396058), array(0.01298701))

# %%
x = np.arange(p.ppf(0.01, mu), p.ppf(0.99, mu))

fig, ax = plt.subplots()

ax.plot(x, p.pmf(x, mu), 'bo', ms=8, label='bernoulli pmf')
ax.vlines(x, 0, p.pmf(x, mu), colors='r', lw=5, alpha=0.5)

plt.axvline(mu, label='quartiles', c='tab:brown', linestyle='dotted')
plt.axvline(var, c='tab:green', linestyle='dotted')

ax.set_xlabel('$x$', fontsize=15)
ax.set_ylabel('$f_x(x)$', fontsize=15)
# ax.vlines(mean, 0.14, 0.16, colors='tab:red')
# ax.vlines(var, 0.14, 0.16, colors='tab:red', linewidth=3)
ax.set_title('Poisson distribution for $\mu=$'+str(mu)+', $\sigma=$'+str(sigma), fontsize=15)
ax.legend(loc='best', frameon=True)
ax.grid(True)
plt.show()

# %%
# @@ Cell 79
import numpy as np
from scipy.stats import bernoulli as bern

p = 0.72
q = 1 - p
mean, var, skew, kurt = bern.stats(p, moments='mvsk')
mean, var

fig, ax = plt.subplots()
x = np.arange(bern.ppf(0.01, p), bern.ppf(0.99, p))
ax.plot(x, bern.pmf(x, p), 'bo', ms=8, label='bernoulli pmf')
ax.vlines(x, 0.72, bern.pmf(x, p), colors='b', lw=5, alpha=0.5)

#x = np.arange(bern.ppf(0.01, p), bern.ppf(0.99, p))
ax.plot(x, bern.pmf(x, q), 'bo', ms=8, label='bernoulli pmf')
ax.vlines(x, 0.28, bern.pmf(x, q), colors='r', lw=5, alpha=0.5)

ax.set_xlabel('$x$', fontsize=15)
ax.set_ylabel('PMF of bernoulli ditribution', fontsize=15)
ax.set_title('Bernoulli PMF for $p=0.72$', fontsize=15)
ax.legend(loc='best', frameon=True)
ax.grid(True)
plt.show()
